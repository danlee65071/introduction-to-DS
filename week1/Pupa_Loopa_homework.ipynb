# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('accountancy.csv')

# %%
data
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
salary_inf = data.groupby(['Type', 'Executor']).aggregate({'Salary' : 'max'})

# %%
salary_inf
# Out:
#                Salary
# Type Executor
# A    Loopa         58
#      Pupa         234
# B    Loopa        249
#      Pupa          77
# C    Loopa        249
#      Pupa          94
# D    Loopa        181
#      Pupa         194
# E    Loopa        220
#      Pupa         197
# F    Loopa        244
#      Pupa         195
