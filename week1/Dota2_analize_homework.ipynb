# %%
import numpy as np
import pandas as pd

# %%
dota_heroes = pd.read_csv('dota_hero_stats.csv')

# %%
dota_heroes
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
zero_legs = dota_heroes.query('legs == 0')
zero_legs
# Out:
#     Unnamed: 0 attack_type  id  legs localized_name                      name  \
# 9            9      Ranged  10     0      Morphling   npc_dota_hero_morphling
# 10          10      Ranged  11     0   Shadow Fiend   npc_dota_hero_nevermore
# 14          14      Ranged  15     0          Razor       npc_dota_hero_razor
# 26          26       Melee  28     0        Slardar     npc_dota_hero_slardar
# 31          31      Ranged  33     0         Enigma      npc_dota_hero_enigma
# 38          38      Ranged  40     0     Venomancer  npc_dota_hero_venomancer
# 45          45      Ranged  47     0          Viper       npc_dota_hero_viper
# 65          65       Melee  67     0        Spectre     npc_dota_hero_spectre
# 87          87       Melee  89     0     Naga Siren  npc_dota_hero_naga_siren
# 89          89      Ranged  91     0             Io        npc_dota_hero_wisp
# 92          92      Ranged  94     0         Medusa      npc_dota_hero_medusa
#
# ...

# %%
num_zero_legs = zero_legs.shape[0]
num_zero_legs
# Out:
# 11

# %%
two_legs = dota_heroes.query('legs == 2')
two_legs
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# 5             5      Ranged    6     2     Drow Ranger
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# 5       npc_dota_hero_drow_ranger          agi
# ...

# %%
num_two_legs = two_legs.shape[0]
num_two_legs
# Out:
# 95

# %%
four_legs = dota_heroes.query('legs == 4')
four_legs
# Out:
#     Unnamed: 0 attack_type  id  legs     localized_name  \
# 2            2      Ranged   3     4               Bane
# 50          50      Ranged  52     4            Leshrac
# 56          56      Ranged  58     4        Enchantress
# 61          61      Ranged  63     4             Weaver
# 74          74      Ranged  76     4  Outworld Devourer
# 94          94       Melee  96     4  Centaur Warrunner
# 95          95       Melee  97     4             Magnus
#
#                                 name primary_attr  \
# 2                 npc_dota_hero_bane          int
# 50             npc_dota_hero_leshrac          int
# 56         npc_dota_hero_enchantress          int
# 61              npc_dota_hero_weaver          agi
# 74  npc_dota_hero_obsidian_destroyer          int
# 94             npc_dota_hero_centaur          str
# 95           npc_dota_hero_magnataur          str
#
#                                                 roles
# ...

# %%
num_four_legs = four_legs.shape[0]
num_four_legs
# Out:
# 7

# %%
six_legs = dota_heroes.query('legs == 6')
six_legs
# Out:
#      Unnamed: 0 attack_type   id  legs localized_name  \
# 15           15       Melee   16     6      Sand King
# 86           86       Melee   88     6   Nyx Assassin
# 103         103      Ranged  105     6        Techies
#
#                            name primary_attr  \
# 15      npc_dota_hero_sand_king          str
# 86   npc_dota_hero_nyx_assassin          agi
# 103       npc_dota_hero_techies          int
#
#                                                  roles
# 15   ['Initiator', 'Disabler', 'Support', 'Nuker', ...
# 86        ['Disabler', 'Nuker', 'Initiator', 'Escape']
# 103                              ['Nuker', 'Disabler']

# %%
num_six_legs = six_legs.shape[0]
num_six_legs
# Out:
# 3

# %%
eight_legs = dota_heroes.query('legs == 8')
eight_legs
# Out:
#     Unnamed: 0 attack_type  id  legs localized_name  \
# 59          59       Melee  61     8    Broodmother
#
#                          name primary_attr  \
# 59  npc_dota_hero_broodmother          agi
#
#                                      roles
# 59  ['Carry', 'Pusher', 'Escape', 'Nuker']

# %%
num_eight_legs = eight_legs.shape[0]
num_eight_legs
# Out:
# 1

# %%
attr = dota_heroes.groupby(['attack_type', 'primary_attr']).aggregate({'Unnamed: 0' : 'count'})

# %%
attr
# Out:
#                           Unnamed: 0
# attack_type primary_attr
# Melee       agi                   19
#             int                    2
#             str                   35
# Ranged      agi                   18
#             int                   40
#             str                    3
